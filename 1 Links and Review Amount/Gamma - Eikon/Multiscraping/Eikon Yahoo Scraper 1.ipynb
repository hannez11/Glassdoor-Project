# %% [markdown]
# # load

# %%
from multiprocessing import pool
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from urllib.parse import unquote
import random
import time
from pathlib import Path
from torpy.http.requests import TorRequests
from itertools import repeat

input = pd.read_csv(r"W:\019_Glassdoor\1 Data\1 Glassdoor Links\2 Eikon Sample\0930_MnA_Sample_Eikon_AcqAndTargets_forYahoo.csv", sep=";", decimal=",", encoding='unicode_escape')

class YahooScraperClass:
    def yahoo_scraper(self, df, sleeptime_max=1, tor_active="no"):
        try: # if operation fails, then return the current df
            firmname = df["full_name_cleaned"]
            print(f"Firm #{df.name + 1}: {firmname}")
            # query = f'site:glassdoor.com {firmname}'.replace(' ', '+') # non-strict
            query = f'site:glassdoor.com "{firmname}"'.replace(' ', '+') #putting {firmname} around "" might help. however, the query might also be too strict not returning any results
            URL = f"https://search.yahoo.com/search?p={query}&vc=en&pz=20"

            # shuffle through user agent list for bot prevention. use IP shuffling to prevent further bot detection
            time.sleep(round(random.uniform(0.25,sleeptime_max), 3))
            USER_AGENTS = ["Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:76.0) Gecko/20100101 Firefox/76.0",
                        "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:103.0) Gecko/20100101 Firefox/103.0",
                        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36",
                        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Safari/537.36",
                        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36 Edg/103.0.1264.71"
                        ]
            headers = {"user-agent":random.choice(USER_AGENTS)}

            ## use tor
            if tor_active=="yes":
                try:
                    url = self.sess.get(URL, headers=headers)
                except:
                    print("Error getting the URL with tor requests")
            ## use regular IP
            else:
                url = requests.get(URL, headers=headers)

            soup = BeautifulSoup(url.content, "html.parser")
            time.sleep(0.2) #to fully load the page

            ## scraper ##
            #############
            link_found = 0
            ## check if amount of ratings is displayed in at least of the search results. if so, grab this number and the parent div containing the link
            if soup.find("li", {"class":["tc", "bxz-bb"]}) and len(soup.find("li", {"class":["tc", "bxz-bb"]}).text)<15: #check length of the classes text, since class is not exclusively used for amount of ratings
                ## grab the review number
                review_amount = soup.find("li", {"class":["tc", "bxz-bb"]}) #only get the first item, since it appears to be most accurate. could be of the last search result
                try: #sometimes "Currency: EUR" is displayed instead of the review amount
                    review_amount_final = review_amount.text.split("(")[1][:-1] #"4/5 (3)"
                    if "K" in review_amount_final: # "5.7K" to 5700
                        review_amount_final = review_amount_final.replace(".", "")
                        review_amount_final = review_amount_final.replace("K", "00")
                    # print(f"review amount: {review_amount_final}")
                    df["review_amount"] = review_amount_final
                    ## grab the href from the parent of the same search result
                except:
                    df["review_amount"] = "" 
                review_parents = review_amount.find_parents("div")
                for link in review_parents:
                    if link.find("a") and "glassdoor" in link.find("a")["href"]:
                        alink = link.find("a")
                        link_found = 1
                        break
            ## if amount of ratings is not on page, then just grab the href
            elif link_found != 1:
                # print("review amount: none found")
                results = soup.findAll("h3")
                for link in results:
                    if link.find("a") and "glassdoor" in link.find("a")["href"]:
                        alink = link.find("a")
                        link_found = 1
                        break
                ## if neither link nor review amount was found
                if link_found != 1:
                    link_found = "no link found" #"no link found"
                    link_final = ""
                    print("no link found on first page")
            
            ## decode href link if link was found ##
            ########################################
            if link_found == 1:
                link_with_yahoo = unquote(alink["href"]) #unquote decodes URLs
                try: # cover weird cases in which an image link is retrieved
                    link_final = link_with_yahoo.split("RU=")[1].split("/RK=2")[0] #https://r.search.yahoo.com/_ylt=A0geK9dD9t9i2BIAtodXNyoA;_ylu=Y29sbwNiZjEEcG9zAzEEdnRpZAMEc2VjA3Ny/RV=2/RE=1658873541/RO=10/RU=https://www.glassdoor.com/Overview/Working-at-California-Micro-Devices-EI_IE1221.11,35.htm/RK=2/RS=Ss7CVR85Jhnt899NkWVSw9eSVUw-
                    if "/Working" in link_final:
                        # from https://www.glassdoor.com/Overview/Working-at-Tesla-EI_IE43129.11,16.htm
                        # to https://www.glassdoor.com/Reviews/Tesla-Reviews-E43129.htm
                        link_final = link_final.replace("/Overview/Working-at-", "/Reviews/") #shouldnt be an issue to replace the /Overview/ part with /Reviews/ even though the original Reviews link looks different
                        link_final = link_final.replace("EI_IE", "Reviews-E") 
                        link_final = link_final.split(".htm")[0][:-6] + ".htm"
                        link_found = "transformed overview link"
                    elif "/Jobs/" in link_final:
                        link_final = link_final.replace("/Jobs/", "/Reviews/")
                        link_final = link_final.replace("-Jobs-", "-Reviews-")
                        link_found = "transformed jobs link"
                    elif "/Salary/" in link_final:
                        link_final = link_final.replace("/Salary/", "/Reviews/")
                        link_final = link_final.replace("-Salaries-", "-Reviews-")
                        link_found = "transformed salary link"
                    elif "/Reviews/" in link_final:
                        link_found = "original review link"
                    else:
                    #elif "/job-listing/" or "/Job/" in link_final:
                        link_found = "wrong link"
                except:
                    link_final = link_with_yahoo
                    
            df["link_yahoo"] = link_final
            df["link_found"] = link_found
            print(link_final, "\n")
            return df
            
        except:
            print("Some error")
            return df

    def tor_yahoo_scraper(self, df_dynamic, startrow=0, endrow=5, tor="no", sleeptime_max=0.5, save_path=Path.home()):
            ## set parameters
            # tor: change to yes or no
            # sleeptime_max: use >2 with original ip (tor = "no"). around 1000 requests possible until temp. ip block

            ## create a copy of the input frame; keep old index as extra column
            df_dynamic = input[startrow:endrow].reset_index(drop=False)

            df_dynamic["link_yahoo"] = np.nan
            df_dynamic["review_amount"] = np.nan
            df_dynamic["link_found"] = np.nan

            ## with Tor-Gateway
            if tor == "yes":
                with TorRequests() as tor_requests:
                    print("Connecting to tor..")
                    with tor_requests.get_session() as self.sess: #sess pulls a request of the page with the tor connection. self is crucial in front of sess. otherwise wont work in the yahoo_scraper method
                        current_ip = self.sess.get("http://httpbin.org/ip").json()
                        print(f"Current IP:{current_ip}; sleeptime: {sleeptime_max}\n")
                        df_dynamic = df_dynamic.apply(self.yahoo_scraper, args=(sleeptime_max, "yes"), axis=1)
            ## without tor
            else:
                df_dynamic = df_dynamic.apply(self.yahoo_scraper, args=(sleeptime_max, "no"), axis=1)

            print(f"Scraping finished for {startrow} to {endrow}")
            
            ## save file with dynamic file name
            dir = Path(save_path)
            path_with_time = Path.joinpath(dir, f'{time.strftime("%m%d")}_MnA_Sample_Eikon_{startrow}_{endrow}.csv')
            df_dynamic.to_csv(path_with_time, sep=";", decimal=",", float_format='%.3f', index=False)
            print(f"{path_with_time} saved")

# %% [markdown]
# # execute

# %%
YahooScraperClass().tor_yahoo_scraper('df_mp1', 300, 499, 'no', 0.2)
# Out:
# Firm #1: Bryn Mawr Bank
# https://www.glassdoor.com/Reviews/Bryn-Mawr-Trust-Reviews-E1196.htm
#
# Firm #2: JDA Software Group
# https://www.glassdoor.com/Job/software-engineer-jda-software-group-inc-jobs-SRCH_KO0,17_KE18,40.htm
#
# Firm #3: Franco-Nevada
# https://www.glassdoor.com/Reviews/Franco-Nevada-Reviews-E8000.htm
#
# Firm #4: IESI-BFC
# no link found on first page
#
#
# Firm #5: SP Telemedia
# no link found on first page
#
#
# Firm #6: Churchill Downs
# https://www.glassdoor.com/Reviews/Churchill-Downs-Reviews-E4795.htm
#
# Firm #7: Blue Note Mining
# no link found on first page
#
#
# Firm #8: Applied Materials
# https://www.glassdoor.com/Reviews/Applied-Materials-Reviews-E1139.htm
#
# Firm #9: Cadillac Ventures
# no link found on first page
#
#
# Firm #10: Angle Energy
# no link found on first page
#
#
# Firm #11: People's United Financial
# https://www.glassdoor.com/Reviews/People-s-United-Bank-Reviews-E199620.htm
#
# Firm #12: Cliffs Natural Resources
# https://www.glassdoor.com/Reviews/Cleveland-Cliffs-Reviews-E157.htm
#
# Firm #13: Entree Gold
# https://www.glassdoor.com/Reviews/Entr%C3%A9e-Gold-Reviews-E39225.htm
#
# Firm #14: A Schulman
# https://www.glassdoor.com/Reviews/A-Schulman-Reviews-E1072.htm
#
# Firm #15: Talbots
# https://www.glassdoor.com/Reviews/Talbots-Reviews-E2435.htm
#
# Firm #16: Actuate
# https://www.glassdoor.com/Reviews/Actuate-Reviews-E7344.htm
#
# Firm #17: Result Energy
# https://www.glassdoor.com/Reviews/CLEAResult-Reviews-E415314.htm
#
# Firm #18: Whitbread
# https://www.glassdoor.com/Reviews/Whitbread-Reviews-E10272.htm
#
# Firm #19: Exxon Mobil
# https://www.glassdoor.com/Reviews/ExxonMobil-Reviews-E237.htm
#
# Firm #20: Mariner Energy
# https://www.glassdoor.com/Reviews/Mariner-Energy-Reviews-E9841.htm
#
# Firm #21: Western Coal
# https://www.glassdoor.com/Reviews/Western-Coalfields-Reviews-E667036.htm
#
# Firm #22: Mears Group
# https://www.glassdoor.com/Reviews/Mears-Group-Reviews-E27342.htm
#
# Firm #23: HMV Group
# https://www.glassdoor.com/Job/hmv-group-jobs-SRCH_KE0,9.htm
#
# Firm #24: Crane
# https://www.glassdoor.com/Reviews/Crane-Crane-Reviews-E7578716.htm
#
# Firm #25: Tower Bancorp
# https://www.glassdoor.com/Reviews/Tower-Bancorp-Reviews-E22122.htm
#
# Firm #26: PetroBakken Energy
# https://www.glassdoor.com/Reviews/TriStar-Oil-and-Gas-Reviews-E23462.htm
#
# Firm #27: Proximagen Neuroscience
# no link found on first page
#
#
# Firm #28: Tiomin Resources
# https://www.glassdoor.com/Reviews/Tiomin-Resources-Reviews-E23774.htm
#
# Firm #29: Cominar Real Estate Investment Trust
# https://www.glassdoor.com/Reviews/Cominar-Reit-Reviews-E17291.htm
#
# Firm #30: Bolero Resources
# no link found on first page
#
#
# Firm #31: Haemonetics
# https://www.glassdoor.com/Reviews/Haemonetics-Reviews-E786.htm
#
# Firm #32: Manpower
# https://www.glassdoor.com/Reviews/Manpower-Reviews-E2548.htm
#
# Firm #33: European Nickel
# https://www.glassdoor.com/Reviews/European-Nickel-Reviews-E35541.htm
#
# Firm #34: FirstEnergy
# https://www.glassdoor.com/Reviews/FirstEnergy-Reviews-E493.htm
#
# Firm #35: Capital Gold
# https://www.glassdoor.com/Reviews/Capital-Gold-Group-Reviews-E1011035.htm
#
# Firm #36: Babcock International Group
# https://www.glassdoor.com/Reviews/Babcock-International-Group-Reviews-E10114.htm
#
# Firm #37: Schlumberger
# https://www.glassdoor.com/Reviews/Schlumberger-Reviews-E588.htm
#
# Firm #38: RR Donnelley and Sons
# https://www.glassdoor.com/Reviews/R-R-Donnelley-Reviews-E554.htm
#
# Firm #39: MSCI
# https://www.glassdoor.com/Reviews/MSCI-Reviews-E14616.htm
#
# Firm #40: Constellation Software
# https://www.glassdoor.com/Reviews/Constellation-Software-Reviews-E16671.htm
#
# Firm #41: Beach Energy
# https://www.glassdoor.com/Reviews/Beach-Energy-Reviews-E2903303.htm
#
# Firm #42: Queenston Mining
# https://www.glassdoor.com/Reviews/Queenston-Mining-Reviews-E23421.htm
#
# Firm #43: Atlas Iron
# https://www.glassdoor.com/Reviews/Atlas-Iron-Reviews-E1005628.htm
#
# Firm #44: Avisen
# no link found on first page
#
#
# Firm #45: Pegasystems
# https://www.glassdoor.com/Reviews/Pegasystems-Reviews-E5936.htm
#
# Firm #46: Osisko Mining
# https://www.glassdoor.com/Reviews/Osisko-Mining-Reviews-E6295892.htm
#
# Firm #47: Mineral Resources
# https://www.glassdoor.com/Reviews/Mineral-Resources-Reviews-E2122177.htm
#
# Firm #48: Cape Lambert Resources
# no link found on first page
#
#
# Firm #49: Timberline Resources
# no link found on first page
#
#
# Firm #50: Avnet
# https://www.glassdoor.com/Reviews/Avnet-Reviews-E66.htm
#
# Firm #51: Grainger
# https://www.glassdoor.com/Reviews/Grainger-Reviews-E711.htm
#
# Firm #52: Agnico Eagle Mines
# https://www.glassdoor.com/Reviews/Agnico-Eagle-Mines-Reviews-E2700590.htm
#
# Firm #53: AZZ
# https://www.glassdoor.com/Reviews/AZZ-Reviews-E1158.htm
#
# Firm #54: SandRidge Energy
# https://www.glassdoor.com/Reviews/SandRidge-Energy-Reviews-E40507.htm
#
# Firm #55: Accelrys
# https://www.glassdoor.com/Reviews/Accelrys-Reviews-E14299.htm
#
# Firm #56: Halliburton
# https://www.glassdoor.com/Reviews/Halliburton-Reviews-E307.htm
#
# Firm #57: RRI Energy
# https://www.glassdoor.com/Reviews/Employee-Review-GenOn-Energy-RVW432668.htm
#
# Firm #58: Apache
# https://www.glassdoor.com/job-listing/geological-advisor-apache-JV_IC1140171_KO0,18_KE19,25.htm?jl=1008172960035
#
# Firm #59: Crown Minerals
# no link found on first page
#
#
# Firm #60: The GEO Group
# https://www.glassdoor.com/Reviews/The-GEO-Group-Reviews-E3661.htm
#
# Firm #61: Donegal Group
# https://www.glassdoor.com/Reviews/Donegal-Insurance-Group-Reviews-E1343.htm
#
# Firm #62: Visa
# https://www.glassdoor.com/Reviews/Visa-Inc-Reviews-E3035.htm
#
# Firm #63: Boralex
# https://www.glassdoor.com/Reviews/Boralex-Reviews-E24220.htm
#
# Firm #64: CGI Group
# https://www.glassdoor.com/Reviews/CGI-Reviews-E8452.htm
#
# Firm #65: Jacksonville Bancorp
# https://www.glassdoor.com/Reviews/Jacksonville-Bancorp-FL-Reviews-E8872.htm
#
# Firm #66: Merit Medical Systems
# https://www.glassdoor.com/Reviews/Merit-Medical-Systems-Reviews-E2079.htm
#
# Firm #67: Universal Health Services
# https://www.glassdoor.com/Reviews/Universal-Health-Services-Inc-Reviews-E2001.htm
#
# Firm #68: The Churchill
# https://www.glassdoor.com/Reviews/The-Churchill-School-And-Center-Reviews-E259682.htm
#
# Firm #69: Toronto-Dominion Bank
# https://www.glassdoor.com/Reviews/TD-bank-Reviews-EI_IE3767.0,2_KO3,7.htm
#
# Firm #70: Pearson
# https://www.glassdoor.com/Reviews/Pearson-Reviews-E3322.htm
#
# Firm #71: Gentiva Health Services
# https://www.glassdoor.com/Reviews/Gentiva-Health-Services-Reviews-E6833869.htm
#
# Firm #72: Kearny Financial
# https://www.glassdoor.com/job-listing/universal-banker-i-part-time-kearny-bank-JV_IC1126835_KO0,28_KE29,40.htm?jl=1007823500489
#
# Firm #73: Travis Perkins
# https://www.glassdoor.com/Reviews/Travis-Perkins-Reviews-E10254.htm
#
# Firm #74: Netcall
# https://www.glassdoor.com/Reviews/Netcall-Reviews-E11677.htm
#
# Firm #75: Sonic Solutions
# https://www.glassdoor.com/Reviews/Sonic-Solutions-Reviews-E2518.htm
#
# Firm #76: VCA Antech
# https://www.glassdoor.com/Job/vca-antech-jobs-SRCH_KO0,10.htm
#
# Firm #77: Conquest Mining Pty
# no link found on first page
#
#
# Firm #78: Allscripts-Misys Healthcare Solutions
# no link found on first page
#
#
# Firm #79: Buckeye Partners
# https://www.glassdoor.com/Reviews/Buckeye-Partners-Reviews-E113.htm
#
# Firm #80: Teledyne Technologies
# https://www.glassdoor.com/Reviews/Teledyne-Technologies-Reviews-E9818.htm
#
# Firm #81: Biovail
# https://www.glassdoor.com/Reviews/Biovail-Reviews-E4163.htm
#
# Firm #82: Ralcorp
# https://www.glassdoor.com/Reviews/Ralcorp-Reviews-E3574.htm
#
# Firm #83: Paramount Gold and Silver
# no link found on first page
#
#
# Firm #84: TIBCO Software
# https://www.glassdoor.com/Reviews/TIBCO-Software-Reviews-E6280.htm
#
# Firm #85: Crescent Point Energy
# https://www.glassdoor.com/Reviews/Crescent-Point-Energy-Reviews-E18570.htm
#
# Firm #86: New Pacific Metals
# https://www.glassdoor.com/Reviews/Pacific-Metals-Group-Reviews-E1035256.htm
#
# Firm #87: Whitefield
# https://www.glassdoor.com/job-listing/cma-certified-medical-assistant-weeks-medical-center-rhc-whitefield-JV_IC1147711_KO0,31_KE32,67.htm?jl=1008174790295
#
# Firm #88: Synchronica
# https://www.glassdoor.com/Reviews/Synchronica-Reviews-E373713.htm
#
# Firm #89: Reckitt Benckiser Group
# https://www.glassdoor.com/job-listing/r-and-d-associate-operations-and-testing-reckitt-JV_IC1126886_KO0,40_KE41,48.htm?jl=1008174829512
#
# Firm #90: Firestone Diamonds
# https://www.glassdoor.com/Reviews/Firestone-Diamonds-Reviews-E12100.htm
#
# Firm #91: Paladin Energy
# https://www.glassdoor.com/Reviews/Paladin-Energy-Reviews-E1827254.htm
#
# Firm #92: Aegis Group
# https://www.glassdoor.com/Reviews/Aegis-Group-of-Companies-Reviews-E311125.htm
#
# Firm #93: Elektron
# https://www.glassdoor.com/Benefits/TTP-Great-Malvern-Benefits-EI_IE366069.0,3_IL.4,17_IC3254763.htm
#
# Firm #94: Stockland Co.rp
# https://www.glassdoor.com/Reviews/Stockland-Reviews-E38097.htm
#
# Firm #95: EnQuest
# https://www.glassdoor.com/Reviews/EnQuest-Reviews-E494326.htm
#
# Firm #96: AP Eagers
# https://www.glassdoor.com/Reviews/AP-Eagers-Group-Reviews-E658971.htm
#
# Firm #97: FNB
# https://www.glassdoor.com/job-listing/customer-service-representative-i-fnb-bank-ky-JV_IC1144063_KO0,33_KE34,45.htm?jl=1008168596708
#
# Firm #98: Saga Group
# https://www.glassdoor.com/Reviews/Saga-Group-Reviews-E37545.htm
#
# Firm #99: Oro Gold Resources
# no link found on first page
#
#
# Firm #100: Emergent Biosolutions
# https://www.glassdoor.com/Reviews/Emergent-BioSolutions-Reviews-E9794.htm
#
# Firm #101: Agrium
# https://www.glassdoor.com/Reviews/AGRIUM-Reviews-E5411582.htm
#
# Firm #102: FLIR Systems
# https://www.glassdoor.com/Reviews/FLIR-Reviews-E2559.htm
#
# Firm #103: Brookfield Infrastructure Partners
# no link found on first page
#
#
# Firm #104: Bravada Gold
# no link found on first page
#
#
# Firm #105: 3M
# https://www.glassdoor.com/Reviews/3M-Reviews-E446.htm
#
# Firm #106: Fronteer Gold
# https://www.glassdoor.com/Reviews/Frontier-Gold-River-Reviews-EI_IE131305.0,8_IL.9,19_IC1163941.htm
#
# Firm #107: Ebix
# https://www.glassdoor.com/Reviews/Ebix-Reviews-E1328.htm
#
# Firm #108: Kodiak Exploration
# no link found on first page
#
#
# Firm #109: Kenexa
# https://www.glassdoor.com/Reviews/Kenexa-Reviews-E12138.htm
#
# Firm #110: Stillwater Mining
# https://www.glassdoor.com/Reviews/Stillwater-Mining-Reviews-E3837.htm
#
# Firm #111: Legacy Oil + Gas
# https://www.glassdoor.com/job-listing/oil-and-gas-petroleum-engineer-intern-conservation-legacy-JV_IC1136949_KO0,37_KE38,57.htm?jl=1007962810717
#
# Firm #112: Anatolia Minerals Development
# https://www.glassdoor.com/Reviews/Anatolia-Minerals-Reviews-E23535.htm
#
# Firm #113: Eurogold
# no link found on first page
#
#
# Firm #114: WR Grace and Co.
# https://www.glassdoor.com/Reviews/W-R-Grace-and-Co-Reviews-E710.htm
#
# Firm #115: Calix
# https://www.glassdoor.com/Reviews/Calix-Reviews-E13819.htm
#
# Firm #116: Discover Financial Services
# https://www.glassdoor.com/Reviews/Discover-Reviews-E13990.htm
#
# Firm #117: Arrow Electronics
# https://www.glassdoor.com/Reviews/Arrow-Electronics-Reviews-E56.htm
#
# Firm #118: Silvermex Resources
# no link found on first page
#
#
# Firm #119: Penn Virginia Resource Partners
# https://www.glassdoor.com/Reviews/Penn-Virginia-Resource-Partners-Reviews-E13455.htm
#
# Firm #120: Fort Chicago Energy Partners
# https://www.glassdoor.com/Reviews/Veresen-Reviews-E14730.htm
#
# Firm #121: Avenir Diversifiedome Trust
# no link found on first page
#
#
# Firm #122: Csg Systems International
# https://www.glassdoor.com/Reviews/CSG-Reviews-E6106.htm
#
# Firm #123: Mega Precious Metals
# no link found on first page
#
#
# Firm #124: Unilever
# https://www.glassdoor.com/Reviews/Unilever-Reviews-E3513.htm
#
# Firm #125: Virtual Radiologic
# https://www.glassdoor.com/Reviews/Virtual-Radiologic-Reviews-E42001.htm
#
# Firm #126: PharMerica
# https://www.glassdoor.com/Reviews/PharMerica-Reviews-E894.htm
#
# Firm #127: Southern Pacific Resource
# https://www.glassdoor.com/Reviews/Southern-Pacific-Resource-Corp-Reviews-E632684.htm
#
# Firm #128: Danaher
# https://www.glassdoor.com/Reviews/Danaher-Reviews-E193.htm
#
# Firm #129: EarthLink
# https://www.glassdoor.com/Reviews/EarthLink-Reviews-E2468573.htm
#
# Firm #130: Gammon Gold
# https://www.glassdoor.com/Reviews/Gammon-Gold-Reviews-E24009.htm
#
# Firm #131: Microsemi
# https://www.glassdoor.com/job-listing/principal-semiconductor-engineer-design-qualdoc-JV_IC1154388_KO0,39_KE40,47.htm?jl=1008168491421
#
# Firm #132: Robbins and Myers
# https://www.glassdoor.com/Reviews/Robbins-and-Myers-Reviews-E1837.htm
#
# Firm #133: Perilya
# https://www.glassdoor.com/Reviews/Perilya-Reviews-E3283624.htm
#
# Firm #134: Old National Bancorp
# https://www.glassdoor.com/Reviews/Old-National-Bancorp-Reviews-E1730.htm
#
# Firm #135: Oil States International
# https://www.glassdoor.com/Reviews/Oil-States-International-Reviews-E12394.htm
#
# Firm #136: Carlisle Cos
# https://www.glassdoor.com/Reviews/Carlisle-Companies-Reviews-E131.htm
#
# Firm #137: Northeast Utilities
# https://www.glassdoor.com/Reviews/Northeast-Utilities-Reviews-E485.htm
#
# Firm #138: Royal Bank Of Canada
# https://www.glassdoor.com/Reviews/RBC-Reviews-E3358.htm
#
# Firm #139: Kingsgate Consolidated
# https://www.glassdoor.com/Reviews/Consolidated-Supply-Kingsgate-Reviews-EI_IE27471.0,19_IL.20,29_IC3799067.htm
#
# Firm #140: Pacificfety Products
# https://www.glassdoor.com/Reviews/Pacific-Products-Group-Reviews-E1706510.htm
#
# Firm #141: Equinox Minerals
# no link found on first page
#
#
# Firm #142: Community Bank System
# https://www.glassdoor.com/Reviews/Community-Bank-System-Reviews-E1287.htm
#
# Firm #143: Terraco Gold
# https://www.glassdoor.com/Reviews/Terraco-Reviews-E17344.htm
#
# Firm #144: CardioNet
# https://www.glassdoor.com/Salaries/cardionet-salary-SRCH_KO0,9.htm
#
# Firm #145: Chevron
# https://www.glassdoor.com/Reviews/Chevron-Reviews-E13524.htm
#
# Firm #146: Quest Software
# https://www.glassdoor.com/Reviews/Quest-Software-Reviews-E9404.htm
#
# Firm #147: Caterpillar
# https://www.glassdoor.com/Reviews/Caterpillar-Reviews-E137.htm
#
# Firm #148: Walter Energy
# https://www.glassdoor.com/Reviews/Jim-Walter-Resources-Reviews-E16675.htm
#
# Firm #149: Bank of Nova Scotia
# https://www.glassdoor.com/Reviews/Scotiabank-Reviews-E11013.htm
#
# Firm #150: BigAir Group
# https://www.glassdoor.com/Reviews/BigAir-Group-Reviews-E954672.htm
#
# Firm #151: Rio Tinto
# https://www.glassdoor.com/Reviews/Rio-Tinto-Reviews-E6685.htm
#
# Firm #152: AGL Resources
# https://www.glassdoor.com/Reviews/AGL-Reviews-E2125156.htm
#
# Firm #153: Nara Bancorp
# no link found on first page
#
#
# Firm #154: Uni-Select
# https://www.glassdoor.com/Reviews/Uni-Select-Reviews-E9362.htm
#
# Firm #155: TransForce
# https://www.glassdoor.com/Reviews/TransForce-Reviews-E873298.htm
#
# Firm #156: Dundee Real Estate Investment Trust
# no link found on first page
#
#
# Firm #157: Uranium One
# https://www.glassdoor.com/Reviews/Uranium-One-Reviews-E20136.htm
#
# Firm #158: Stanley Black and Decker
# https://www.glassdoor.com/Reviews/Stanley-Black-and-Decker-Reviews-E350350.htm
#
# Firm #159: Norwood Financial
# https://www.glassdoor.com/Reviews/Norwood-Financial-Reviews-E8031.htm
#
# Firm #160: United Bankshares
# https://www.glassdoor.com/Reviews/United-Bankshares-Reviews-E1987.htm
#
# Firm #161: American National Bankshares
# https://www.glassdoor.com/Reviews/American-National-Bank-and-Trust-Company-Reviews-E1918336.htm
#
# Firm #162: Bank of Montreal
# https://www.glassdoor.com/Reviews/BMO-Financial-Group-Reviews-E3765.htm
#
# Firm #163: Cumulus Media
# https://www.glassdoor.com/Reviews/CUMULUS-MEDIA-Reviews-E7959.htm
#
# Firm #164: Duluth Metals
# https://www.glassdoor.com/Job/duluth-metals-jobs-SRCH_IL.0,6_IC1155612_KO7,13.htm
#
# Firm #165: NovaGold Resources
# https://www.glassdoor.com/Reviews/NovaGold-Reviews-E23147.htm
#
# Firm #166: Hancock Holding
# https://www.glassdoor.com/Reviews/Hancock-Whitney-Bank-Reviews-E832.htm
#
# Firm #167: Rovi
# https://www.glassdoor.com/Reviews/ROVI-Pharmaceuticals-Reviews-E100285.htm
#
# Firm #168: TVI Pacific
# https://www.glassdoor.com/Reviews/TVI-Pacific-Reviews-E24082.htm
#
# Firm #169: Magnum Hunter Resources
# https://www.glassdoor.com/Salaries/magnum-hunter-resources-salary-SRCH_KE0,23.htm
#
# Firm #170: IDEX
# https://www.glassdoor.com/Reviews/IDEX-Reviews-E344.htm
#
# Firm #171: Corelogic
# https://www.glassdoor.com/Reviews/CoreLogic-Reviews-E30994.htm
#
# Firm #172: Levon Resources
# no link found on first page
#
#
# Firm #173: Coleman Cable
# https://www.glassdoor.com/Reviews/Coleman-Cable-Reviews-E15086.htm
#
# Firm #174: Rock-Tenn
# https://www.glassdoor.com/Reviews/Rock-Tenn-Reviews-E8838.htm
#
# Firm #175: RAIT Financial Trust
# https://www.glassdoor.com/Reviews/RAIT-Financial-Trust-Reviews-E7584.htm
#
# Firm #176: Amb Property
# https://www.glassdoor.com/job-listing/asst-dir-amb-property-mgmt-cooper-university-health-care-JV_KO0,26_KE27,56.htm?jl=1007854096669
#
# Firm #177: Alpha Natural Resources
# https://www.glassdoor.com/Reviews/Alpha-Natural-Resources-Reviews-E32918.htm
#
# Firm #178: Time Warner Cable
# https://www.glassdoor.com/Reviews/Time-Warner-Cable-Reviews-E4297719.htm
#
# Firm #179: Taleo
# https://www.glassdoor.com/job-listing/hcm-taleo-specialist-bealls-JV_IC1154335_KO0,20_KE21,27.htm?jl=1008172955672
#
# Firm #180: Sennen Resources
# no link found on first page
#
#
# Firm #181: Newmont Mining
# https://www.glassdoor.com/Reviews/Newmont-Reviews-E479.htm
#
# Firm #182: EP Global Opportunities Trust
# no link found on first page
#
#
# Firm #183: Ensco
# https://www.glassdoor.com/Reviews/ENSCO-Reviews-E194237.htm
#
# Firm #184: DSW
# https://www.glassdoor.com/Reviews/DSW-Reviews-E38052.htm
#
# Firm #185: Independence Group
# https://www.glassdoor.com/Reviews/Independence-Group-Reviews-E1423381.htm
#
# Firm #186: Carillion
# https://www.glassdoor.com/Reviews/Al-Futtaim-Carillion-Reviews-E539320.htm
#
# Firm #187: Sinclair Pharma
# https://www.glassdoor.com/Reviews/Sinclair-Pharma-Reviews-E35395.htm
#
# Firm #188: Renegade Petroleum
# no link found on first page
#
#
# Firm #189: Denison Mines
# https://www.glassdoor.com/Reviews/Denison-Mines-Reviews-E40059.htm
#
# Firm #190: Eternal Energy
# no link found on first page
#
#
# Firm #191: Ventas
# https://www.glassdoor.com/job-listing/chief-engineer-ventas-inc-JV_IC1148208_KO0,14_KE15,25.htm?jl=1008175393258
#
# Firm #192: Johnson Controls
# https://www.glassdoor.com/Reviews/Johnson-Controls-Reviews-E365.htm
#
# Firm #193: eBet
# no link found on first page
#
#
# Firm #194: Africa Oil
# https://www.glassdoor.com/Reviews/Africa-Oil-Reviews-E725154.htm
#
# Firm #195: Vallar (NOW 0A8987)
# no link found on first page
#
#
# Firm #196: Kirby
# https://www.glassdoor.com/Reviews/Kirby-Inland-Marine-Reviews-E18368.htm
#
# Firm #197: Berkshire Hathaway
# https://www.glassdoor.com/Reviews/Berkshire-Hathaway-Reviews-E805672.htm
#
# Firm #198: White Tiger Gold
# no link found on first page
#
#
# Firm #199: PetroFrontier
# no link found on first page
#
#
# Scraping finished for 300 to 499
# C:\Users\Hannes\1001_MnA_Sample_Eikon_300_499.csv saved

# %% [markdown]
# ### create args for tor_yahoo_scraper method

# %%
def create_pool_args(
        first_row=0,
        lastrow=input.shape[0], 
        rows_per_pool=500,
        tor="yes"):

        startrows = [i for i in range (first_row,lastrow,rows_per_pool)]
        endrows = [i for i in range (rows_per_pool-1,lastrow,rows_per_pool)]

        dfs_multi_namelist = [f"df_mp{i}" for i in range(len(startrows))]

        dfs_multi = {name: pd.DataFrame() for name in dfs_multi_namelist}

        pool_args = list(zip(dfs_multi_namelist, startrows, endrows, repeat(tor), repeat(0.5)))
        
        for i in pool_args:
            print(i)

create_pool_args()
# Out:
# ('df_mp0', 0, 499, 'yes', 0.5)
# ('df_mp1', 500, 999, 'yes', 0.5)
# ('df_mp2', 1000, 1499, 'yes', 0.5)
# ('df_mp3', 1500, 1999, 'yes', 0.5)
# ('df_mp4', 2000, 2499, 'yes', 0.5)
# ('df_mp5', 2500, 2999, 'yes', 0.5)
# ('df_mp6', 3000, 3499, 'yes', 0.5)
# ('df_mp7', 3500, 3999, 'yes', 0.5)
# ('df_mp8', 4000, 4499, 'yes', 0.5)
# ('df_mp9', 4500, 4999, 'yes', 0.5)
# ('df_mp10', 5000, 5499, 'yes', 0.5)
# ('df_mp11', 5500, 5999, 'yes', 0.5)
# ('df_mp12', 6000, 6499, 'yes', 0.5)
# ('df_mp13', 6500, 6999, 'yes', 0.5)
# ('df_mp14', 7000, 7499, 'yes', 0.5)
