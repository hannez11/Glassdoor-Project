# %% [markdown]
# # load

# %%
from multiprocessing import pool
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from urllib.parse import unquote
import random
import time
from pathlib import Path
from torpy.http.requests import TorRequests
from itertools import repeat

input = pd.read_csv(r"W:\019_Glassdoor\1 Data\1 Glassdoor Links\2 Eikon Sample\0930_MnA_Sample_Eikon_AcqAndTargets_forYahoo.csv", sep=";", decimal=",", encoding='unicode_escape')

class YahooScraperClass:
    def yahoo_scraper(self, df, sleeptime_max=1, tor_active="no"):
        try: # if operation fails, then return the current df
            firmname = df["full_name_cleaned"]
            print(f"Firm #{df.name + 1}: {firmname}")
            # query = f'site:glassdoor.com {firmname}'.replace(' ', '+') # non-strict
            query = f'site:glassdoor.com "{firmname}"'.replace(' ', '+') #putting {firmname} around "" might help. however, the query might also be too strict not returning any results
            URL = f"https://search.yahoo.com/search?p={query}&vc=en&pz=20"

            # shuffle through user agent list for bot prevention. use IP shuffling to prevent further bot detection
            time.sleep(round(random.uniform(0.25,sleeptime_max), 3))
            USER_AGENTS = ["Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:76.0) Gecko/20100101 Firefox/76.0",
                        "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:103.0) Gecko/20100101 Firefox/103.0",
                        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36",
                        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Safari/537.36",
                        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36 Edg/103.0.1264.71"
                        ]
            headers = {"user-agent":random.choice(USER_AGENTS)}

            ## use tor
            if tor_active=="yes":
                try:
                    url = self.sess.get(URL, headers=headers)
                except:
                    print("Error getting the URL with tor requests")
            ## use regular IP
            else:
                url = requests.get(URL, headers=headers)

            soup = BeautifulSoup(url.content, "html.parser")
            time.sleep(0.2) #to fully load the page

            ## scraper ##
            #############
            link_found = 0
            ## check if amount of ratings is displayed in at least of the search results. if so, grab this number and the parent div containing the link
            if soup.find("li", {"class":["tc", "bxz-bb"]}) and len(soup.find("li", {"class":["tc", "bxz-bb"]}).text)<15: #check length of the classes text, since class is not exclusively used for amount of ratings
                ## grab the review number
                review_amount = soup.find("li", {"class":["tc", "bxz-bb"]}) #only get the first item, since it appears to be most accurate. could be of the last search result
                try: #sometimes "Currency: EUR" is displayed instead of the review amount
                    review_amount_final = review_amount.text.split("(")[1][:-1] #"4/5 (3)"
                    if "K" in review_amount_final: # "5.7K" to 5700
                        review_amount_final = review_amount_final.replace(".", "")
                        review_amount_final = review_amount_final.replace("K", "00")
                    # print(f"review amount: {review_amount_final}")
                    df["review_amount"] = review_amount_final
                    ## grab the href from the parent of the same search result
                except:
                    df["review_amount"] = "" 
                review_parents = review_amount.find_parents("div")
                for link in review_parents:
                    if link.find("a") and "glassdoor" in link.find("a")["href"]:
                        alink = link.find("a")
                        link_found = 1
                        break
            ## if amount of ratings is not on page, then just grab the href
            elif link_found != 1:
                # print("review amount: none found")
                results = soup.findAll("h3")
                for link in results:
                    if link.find("a") and "glassdoor" in link.find("a")["href"]:
                        alink = link.find("a")
                        link_found = 1
                        break
                ## if neither link nor review amount was found
                if link_found != 1:
                    link_found = "no link found" #"no link found"
                    link_final = ""
                    print("no link found on first page")
            
            ## decode href link if link was found ##
            ########################################
            if link_found == 1:
                link_with_yahoo = unquote(alink["href"]) #unquote decodes URLs
                try: # cover weird cases in which an image link is retrieved
                    link_final = link_with_yahoo.split("RU=")[1].split("/RK=2")[0] #https://r.search.yahoo.com/_ylt=A0geK9dD9t9i2BIAtodXNyoA;_ylu=Y29sbwNiZjEEcG9zAzEEdnRpZAMEc2VjA3Ny/RV=2/RE=1658873541/RO=10/RU=https://www.glassdoor.com/Overview/Working-at-California-Micro-Devices-EI_IE1221.11,35.htm/RK=2/RS=Ss7CVR85Jhnt899NkWVSw9eSVUw-
                    if "/Working" in link_final:
                        # from https://www.glassdoor.com/Overview/Working-at-Tesla-EI_IE43129.11,16.htm
                        # to https://www.glassdoor.com/Reviews/Tesla-Reviews-E43129.htm
                        link_final = link_final.replace("/Overview/Working-at-", "/Reviews/") #shouldnt be an issue to replace the /Overview/ part with /Reviews/ even though the original Reviews link looks different
                        link_final = link_final.replace("EI_IE", "Reviews-E") 
                        link_final = link_final.split(".htm")[0][:-6] + ".htm"
                        link_found = "transformed overview link"
                    elif "/Jobs/" in link_final:
                        link_final = link_final.replace("/Jobs/", "/Reviews/")
                        link_final = link_final.replace("-Jobs-", "-Reviews-")
                        link_found = "transformed jobs link"
                    elif "/Salary/" in link_final:
                        link_final = link_final.replace("/Salary/", "/Reviews/")
                        link_final = link_final.replace("-Salaries-", "-Reviews-")
                        link_found = "transformed salary link"
                    elif "/Reviews/" in link_final:
                        link_found = "original review link"
                    else:
                    #elif "/job-listing/" or "/Job/" in link_final:
                        link_found = "wrong link"
                except:
                    link_final = link_with_yahoo
                    
            df["link_yahoo"] = link_final
            df["link_found"] = link_found
            print(link_final, "\n")
            return df
            
        except:
            print("Some error")
            return df

    def tor_yahoo_scraper(self, df_dynamic, startrow=0, endrow=5, tor="no", sleeptime_max=0.5, save_path=Path.home()):
            ## set parameters
            # tor: change to yes or no
            # sleeptime_max: use >2 with original ip (tor = "no"). around 1000 requests possible until temp. ip block

            ## create a copy of the input frame; keep old index as extra column
            df_dynamic = input[startrow:endrow].reset_index(drop=False)

            df_dynamic["link_yahoo"] = np.nan
            df_dynamic["review_amount"] = np.nan
            df_dynamic["link_found"] = np.nan

            ## with Tor-Gateway
            if tor == "yes":
                with TorRequests() as tor_requests:
                    print("Connecting to tor..")
                    with tor_requests.get_session() as self.sess: #sess pulls a request of the page with the tor connection. self is crucial in front of sess. otherwise wont work in the yahoo_scraper method
                        current_ip = self.sess.get("http://httpbin.org/ip").json()
                        print(f"Current IP:{current_ip}; sleeptime: {sleeptime_max}\n")
                        df_dynamic = df_dynamic.apply(self.yahoo_scraper, args=(sleeptime_max, "yes"), axis=1)
            ## without tor
            else:
                df_dynamic = df_dynamic.apply(self.yahoo_scraper, args=(sleeptime_max, "no"), axis=1)

            print(f"Scraping finished for {startrow} to {endrow}")
            
            ## save file with dynamic file name
            dir = Path(save_path)
            path_with_time = Path.joinpath(dir, f'{time.strftime("%m%d")}_MnA_Sample_Eikon_{startrow}_{endrow}.csv')
            df_dynamic.to_csv(path_with_time, sep=";", decimal=",", float_format='%.3f', index=False)
            print(f"{path_with_time} saved")

# %% [markdown]
# # execute

# %%
YahooScraperClass().tor_yahoo_scraper('df_mp2', 4000, 4499, 'yes', 0.2)
# Out:
# _ssl.c:980: The handshake operation timed out
# [ignored] torpy.cell_socket.TorSocketConnectError: _ssl.c:980: The handshake operation timed out
# Retry with another guard...
# Connecting to tor..
# Current IP:{'origin': '5.45.102.119'}; sleeptime: 0.2
#
# Firm #1: Amerigroup
# https://www.glassdoor.com/Reviews/Amerigroup-Reviews-E12022.htm
#
# Firm #2: FX Alliance
# https://www.glassdoor.com/Reviews/FX-Alliance-Reviews-E193424.htm
#
# Firm #3: Compton Petroleum
# https://www.glassdoor.com/Job/compton-petroleum-jobs-SRCH_IL.0,7_IC1146767_KO8,17.htm
#
# Firm #4: Titan Europe
# https://www.glassdoor.com/Reviews/Titan-Europe-Reviews-E36117.htm
#
# Firm #5: Fidelity Bancorp
# https://www.glassdoor.com/Reviews/Fidelity-Bancorp-Funding-Reviews-E2464745.htm
#
# Firm #6: Callisto Pharmaceuticals
# https://www.glassdoor.com/Reviews/Synergy-Pharmaceuticals-Reviews-E38032.htm
#
# Firm #7: GenOn Energy
# https://www.glassdoor.com/Reviews/GenOn-Energy-Reviews-E381442.htm
#
# Firm #8: RailAmerica
# https://www.glassdoor.com/Reviews/RailAmerica-Reviews-E5014.htm
#
# Firm #9: GeoEye
# https://www.glassdoor.com/Reviews/GeoEye-Reviews-E7371990.htm
#
# Firm #10: AuthenTec
# https://www.glassdoor.com/Reviews/AuthenTec-Reviews-E20512.htm
#
# Firm #11: The Shaw Group
# https://www.glassdoor.com/Reviews/The-Shaw-Group-Canada-Reviews-E2343774.htm
#
# Firm #12: NextWave Wireless
# https://www.glassdoor.com/Reviews/NextWave-Wireless-Reviews-E5990.htm
#
# Firm #13: Community Financial
# https://www.glassdoor.com/Reviews/Community-Financial-Credit-Union-Reviews-E856727.htm
#
# Firm #14: Integra Mining
# no link found on first page
#
#
# Firm #15: Avion Gold
# no link found on first page
#
#
# Firm #16: US Home Systems
# https://www.glassdoor.com/Reviews/US-Home-Systems-Reviews-E8875.htm
#
# Firm #17: Savannah Bancorp
# https://www.glassdoor.com/Reviews/Savannah-Bancorp-Reviews-E5034.htm
#
# Firm #18: Robbins and Myers
# https://www.glassdoor.com/Reviews/Robbins-and-Myers-Reviews-E1837.htm
#
# Firm #19: CMS Bancorp
# https://www.glassdoor.com/Reviews/CMS-Bancorp-Reviews-E229959.htm
#
# Firm #20: eDiets.com
# https://www.glassdoor.com/Reviews/eDiets-com-Reviews-E11366.htm
#
# Firm #21: Comverse Technology
# https://www.glassdoor.com/Reviews/Comverse-Wakefield-Reviews-EI_IE35289.0,8_IL.9,18_IC1154701.htm
#
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xa6\xb6\x10\\', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'q\x0f\x19\xb4', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xd2_\xc5\x85', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\x1b\xc3d\xb1', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'%9X\x11', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xa3|\xc3\xa7', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (360 bytes)), stream_id = 31, digest = b'=\x06\xb1\xf7', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'U\x8b\x05\xaa', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'Q\xa7\xf7\x0f', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xdb\xc2CU', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'u\x1a\xad0', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'}>mJ', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\x16P\x9d\xd3', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xcd\xd3\xe9U', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'3\x1f4J', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b't\x81\x92f', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xbe\x95\xe9\xe7', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (272 bytes)), stream_id = 31, digest = b'\xe7;;\xf0', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xd7\xb0\xe6\xf9', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'M\xf3\x9b\n', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\x9er\xcf\x87', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\x05f\xf2\x03', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xe9y\x10P', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xcc\xa9k\xa4', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xcf\xc3{\x97', circuit_id = 8000000e))
# Error getting the URL with tor requests
# Some error
# Firm #108: PVF Capital
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xf6`Qr', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (360 bytes)), stream_id = 31, digest = b'\x8a\x9c\xfa\x97', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xa1\x93 \x92', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'Bzb\xc8', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (452 bytes)), stream_id = 31, digest = b'A\xd1\xd9?', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xb3~X\xe6', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\x0b\xbe\xf5\t', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xa6\xdf\xea\xe3', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'[\xd1\xd0,', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\x8dJF\x95', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'Cf\xe3\xe1', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xdf`\xb3e', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'0_p\\', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (360 bytes)), stream_id = 31, digest = b'\x1f\xc2\xb6\xc1', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xef\xe7\xfe3', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'Cv\xba\x9f', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\x7f\x8b\xb6\xdc', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\x96\xf5\xf9M', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xec\x92\x0b\xfc', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\t=~^', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b"\x8d'\xa5w", circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'5\xa2\xad\x80', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xdb-\xae\xc5', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xa5\xfb\xde,', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\x9fr\xd8]', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (314 bytes)), stream_id = 31, digest = b'\t)L^', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xbe4\xd4\x8b', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xe7j%\x9b', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\x0c\xe7\xc6\xe5', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'u\x1f\x8e\xbb', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (432 bytes)), stream_id = 31, digest = b'\x8f\x9c\xa80', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'+.t6', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xf6\x1a\xa4\xae', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'$\xe4\xa10', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'D\xc2r\xb4', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\x0c\xf3y\xdb', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xdc`\xa2\xec', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'2\x1c\xc3)', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xc3o$\x8d', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\x96\xe3m\xed', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xce\xd9\t\x0c', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xff#\xd4F', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'pd\xbe\xea', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\x17\xc8\xf0]', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'Z\x95\x8aC', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xfc\x8ev\xdc', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\x8a\xe6UN', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xe2s\nI', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'S\x1b*\x8a', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'7\xbfD~', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'|\xa5\xa7\xaf', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'"r\x068', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xce\xcc\xa5\x08', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xf9Z~v', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'a\xde\x02\x15', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xb0\xf4\xac7', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xe8\xe0\xdb_', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\x8b\x92\x19K', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (289 bytes)), stream_id = 31, digest = b'yN\xea\xb5', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\x83_\xf3\xf6', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xf1\x8b\x00\x84', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (452 bytes)), stream_id = 31, digest = b'?\xe7\xdcO', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xb0\xcbrX', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xcfq/\xda', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\x04CE\xac', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'8\xa2J`', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xbd\xe1\xe4\xdf', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (406 bytes)), stream_id = 31, digest = b'P\xed\xcd\x8d', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'1\x98\xce{', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\x89\xd5\xf1U', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xf7\xd7Pd', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'$\x11\x00\x0c', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 31, digest = b'\xa3\xbbI\xbc', circuit_id = 8000000e))
# Stream #31 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (56 bytes)), stream_id = 31, digest = b'\xf86\xc3\x81', circuit_id = 8000000e))
# https://www.glassdoor.com/Salaries/lithonia-staff-engineer-salary-SRCH_IL.0,8_IC1155645_KO9,23.htm
#
# Firm #109: OfficeMax
# https://www.glassdoor.com/Reviews/OfficeMax-Reviews-E103.htm
#
# Firm #110: First Financial
# https://www.glassdoor.com/Reviews/First-Financial-Bank-Reviews-E1410.htm
#
# Firm #111: Berry Petroleum
# https://www.glassdoor.com/Reviews/Berry-Reviews-E96.htm
#
# Firm #112: Aurizon Mines

# %% [markdown]
# ### create args for tor_yahoo_scraper method

# %%
def create_pool_args(
        first_row=0,
        lastrow=input.shape[0], 
        rows_per_pool=100,
        tor="yes"):

        startrows = [i for i in range (first_row,lastrow,rows_per_pool)]
        endrows = [i for i in range (rows_per_pool-1,lastrow,rows_per_pool)]

        dfs_multi_namelist = [f"df_mp{i}" for i in range(len(startrows))]

        dfs_multi = {name: pd.DataFrame() for name in dfs_multi_namelist}

        pool_args = list(zip(dfs_multi_namelist, startrows, endrows, repeat(tor), repeat(0.5)))
        
        for i in pool_args:
            print(i)

create_pool_args()
# Out:
# ('df_mp0', 0, 99, 'yes', 0.5)
# ('df_mp1', 100, 199, 'yes', 0.5)
# ('df_mp2', 200, 299, 'yes', 0.5)
# ('df_mp3', 300, 399, 'yes', 0.5)
# ('df_mp4', 400, 499, 'yes', 0.5)
# ('df_mp5', 500, 599, 'yes', 0.5)
# ('df_mp6', 600, 699, 'yes', 0.5)
# ('df_mp7', 700, 799, 'yes', 0.5)
# ('df_mp8', 800, 899, 'yes', 0.5)
# ('df_mp9', 900, 999, 'yes', 0.5)
# ('df_mp10', 1000, 1099, 'yes', 0.5)
# ('df_mp11', 1100, 1199, 'yes', 0.5)
# ('df_mp12', 1200, 1299, 'yes', 0.5)
# ('df_mp13', 1300, 1399, 'yes', 0.5)
# ('df_mp14', 1400, 1499, 'yes', 0.5)
# ('df_mp15', 1500, 1599, 'yes', 0.5)
# ('df_mp16', 1600, 1699, 'yes', 0.5)
# ('df_mp17', 1700, 1799, 'yes', 0.5)
# ('df_mp18', 1800, 1899, 'yes', 0.5)
# ('df_mp19', 1900, 1999, 'yes', 0.5)
# ('df_mp20', 2000, 2099, 'yes', 0.5)
# ('df_mp21', 2100, 2199, 'yes', 0.5)
# ('df_mp22', 2200, 2299, 'yes', 0.5)
# ('df_mp23', 2300, 2399, 'yes', 0.5)
# ('df_mp24', 2400, 2499, 'yes', 0.5)
# ('df_mp25', 2500, 2599, 'yes', 0.5)
# ('df_mp26', 2600, 2699, 'yes', 0.5)
# ('df_mp27', 2700, 2799, 'yes', 0.5)
# ('df_mp28', 2800, 2899, 'yes', 0.5)
# ('df_mp29', 2900, 2999, 'yes', 0.5)
# ('df_mp30', 3000, 3099, 'yes', 0.5)
# ('df_mp31', 3100, 3199, 'yes', 0.5)
# ('df_mp32', 3200, 3299, 'yes', 0.5)
# ('df_mp33', 3300, 3399, 'yes', 0.5)
# ('df_mp34', 3400, 3499, 'yes', 0.5)
# ('df_mp35', 3500, 3599, 'yes', 0.5)
# ('df_mp36', 3600, 3699, 'yes', 0.5)
# ('df_mp37', 3700, 3799, 'yes', 0.5)
# ('df_mp38', 3800, 3899, 'yes', 0.5)
# ('df_mp39', 3900, 3999, 'yes', 0.5)
# ('df_mp40', 4000, 4099, 'yes', 0.5)
# ('df_mp41', 4100, 4199, 'yes', 0.5)
# ('df_mp42', 4200, 4299, 'yes', 0.5)
# ('df_mp43', 4300, 4399, 'yes', 0.5)
# ('df_mp44', 4400, 4499, 'yes', 0.5)
# ('df_mp45', 4500, 4599, 'yes', 0.5)
# ('df_mp46', 4600, 4699, 'yes', 0.5)
# ('df_mp47', 4700, 4799, 'yes', 0.5)
# ('df_mp48', 4800, 4899, 'yes', 0.5)
# ('df_mp49', 4900, 4999, 'yes', 0.5)
# ('df_mp50', 5000, 5099, 'yes', 0.5)
# ('df_mp51', 5100, 5199, 'yes', 0.5)
# ('df_mp52', 5200, 5299, 'yes', 0.5)
# ('df_mp53', 5300, 5399, 'yes', 0.5)
# ('df_mp54', 5400, 5499, 'yes', 0.5)
# ('df_mp55', 5500, 5599, 'yes', 0.5)
# ('df_mp56', 5600, 5699, 'yes', 0.5)
# ('df_mp57', 5700, 5799, 'yes', 0.5)
# ('df_mp58', 5800, 5899, 'yes', 0.5)
# ('df_mp59', 5900, 5999, 'yes', 0.5)
# ('df_mp60', 6000, 6099, 'yes', 0.5)
# ('df_mp61', 6100, 6199, 'yes', 0.5)
# ('df_mp62', 6200, 6299, 'yes', 0.5)
# ('df_mp63', 6300, 6399, 'yes', 0.5)
# ('df_mp64', 6400, 6499, 'yes', 0.5)
# ('df_mp65', 6500, 6599, 'yes', 0.5)
# ('df_mp66', 6600, 6699, 'yes', 0.5)
# ('df_mp67', 6700, 6799, 'yes', 0.5)
# ('df_mp68', 6800, 6899, 'yes', 0.5)
# ('df_mp69', 6900, 6999, 'yes', 0.5)
# ('df_mp70', 7000, 7099, 'yes', 0.5)
# ('df_mp71', 7100, 7199, 'yes', 0.5)
# ('df_mp72', 7200, 7299, 'yes', 0.5)
# ('df_mp73', 7300, 7399, 'yes', 0.5)
# ('df_mp74', 7400, 7499, 'yes', 0.5)
# ('df_mp75', 7500, 7599, 'yes', 0.5)
# ('df_mp76', 7600, 7699, 'yes', 0.5)
# ('df_mp77', 7700, 7799, 'yes', 0.5)
