# %% [markdown]
# # Grab glassdoor links and review amounts

# %% [markdown]
# ### Load dataframe

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from urllib.parse import unquote
import random
import time
from pathlib import Path
from torpy.http.requests import TorRequests

pd.options.mode.chained_assignment = None  # default='warn'

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
input = pd.read_csv(r"W:\019_Glassdoor\1 Data\1 Glassdoor Links\0813_UniqueFirmList.csv", sep=";", decimal=",", encoding='unicode_escape')

# %% [markdown]
# ## yahoo scraper

# %% [markdown]
# #### proxy rotation via tor

# %%
def yahoo_scraper(df, sleeptime_max=1, tor_active="no"):
    try: #if operation fails, then return the current df
        firmname = df["CompanyName"]
        print(f"Firm #{df.name + 1}: {firmname}")
        # query = f'site:glassdoor.com {firmname}'.replace(' ', '+')
        query = f'site:glassdoor.com "{firmname}"'.replace(' ', '+') #putting {firmname} around "" might help. however, the query might also be too strict not returning any results
        URL = f"https://search.yahoo.com/search?p={query}&vc=en&pz=20"

        ## shuffle through user agent list for bot prevention. use IP shuffling to prevent further bot detection
        time.sleep(round(random.uniform(0.25,sleeptime_max), 3))
        USER_AGENTS = ["Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:76.0) Gecko/20100101 Firefox/76.0",
                    "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:103.0) Gecko/20100101 Firefox/103.0",
                    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36",
                    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.61 Safari/537.36",
                    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36 Edg/103.0.1264.71"
                    ]
        headers = {"user-agent":random.choice(USER_AGENTS)}

        ## use tor
        if tor_active=="yes":
            url = sess.get(URL, headers=headers)
        ## use regular IP
        else:
            url = requests.get(URL, headers=headers)

        soup = BeautifulSoup(url.content, "html.parser")
        time.sleep(0.2) #to fully load the page

        ## scraper ##
        #############

        link_found = 0
        ## check if amount of ratings is displayed in at least of the search results. if so, grab this number and the parent div containing the link
        if soup.find("li", {"class":["tc", "bxz-bb"]}) and len(soup.find("li", {"class":["tc", "bxz-bb"]}).text)<15: #check length of the classes text, since class is not exclusively used for amount of ratings
            ## grab the review number
            review_amount = soup.find("li", {"class":["tc", "bxz-bb"]}) #only get the first item, since it appears to be most accurate. could be of the last search result
            try: #sometimes "Currency: EUR" is displayed instead of the review amount
                review_amount_final = review_amount.text.split("(")[1][:-1] #"4/5 (3)"
                if "K" in review_amount_final: # "5.7K" to 5700
                    review_amount_final = review_amount_final.replace(".", "")
                    review_amount_final = review_amount_final.replace("K", "00")
                # print(f"review amount: {review_amount_final}")
                df["review_amount"] = review_amount_final
                ## grab the href from the parent of the same search result
            except:
                df["review_amount"] = "" 
            review_parents = review_amount.find_parents("div")
            for link in review_parents:
                if link.find("a") and "glassdoor" in link.find("a")["href"]:
                    alink = link.find("a")
                    link_found = 1
                    break
        ## if amount of ratings is not on page, then just grab the href
        elif link_found != 1:
            # print("review amount: none found")
            results = soup.findAll("h3")
            for link in results:
                if link.find("a") and "glassdoor" in link.find("a")["href"]:
                    alink = link.find("a")
                    link_found = 1
                    break
        ## if neither link nor review amount was found
            if link_found != 1:
                link_found = "no link found" #"no link found"
                link_final = ""
                print("no link found")

        
        ## decode href link if link was found ##

        if link_found == 1:
            link_with_yahoo = unquote(alink["href"]) #unquote decodes URLs
            try: #weird cases in which an image link is retrieved
                link_final = link_with_yahoo.split("RU=")[1].split("/RK=2")[0] #https://r.search.yahoo.com/_ylt=A0geK9dD9t9i2BIAtodXNyoA;_ylu=Y29sbwNiZjEEcG9zAzEEdnRpZAMEc2VjA3Ny/RV=2/RE=1658873541/RO=10/RU=https://www.glassdoor.com/Overview/Working-at-California-Micro-Devices-EI_IE1221.11,35.htm/RK=2/RS=Ss7CVR85Jhnt899NkWVSw9eSVUw-
                if "/Working" in link_final:
                    # from https://www.glassdoor.com/Overview/Working-at-Tesla-EI_IE43129.11,16.htm
                    # to https://www.glassdoor.com/Reviews/Tesla-Reviews-E43129.htm
                    link_final = link_final.replace("/Overview/Working-at-", "/Reviews/") #shouldnt be an issue to replace the /Overview/ part with /Reviews/ even though the original Reviews link looks different
                    link_final = link_final.replace("EI_IE", "Reviews-E") 
                    link_final = link_final.split(".htm")[0][:-6] + ".htm"
                    link_found = "transformed overview link"
                elif "/Jobs/" in link_final:
                    link_final = link_final.replace("/Jobs/", "/Reviews/")
                    link_final = link_final.replace("-Jobs-", "-Reviews-")
                    link_found = "transformed jobs link"
                elif "/Salary/" in link_final:
                    link_final = link_final.replace("/Salary/", "/Reviews/")
                    link_final = link_final.replace("-Salaries-", "-Reviews-")
                    link_found = "transformed salary link"
                elif "/Reviews/" in link_final:
                    link_found = "original review link"
                else:
                #elif "/job-listing/" or "/Job/" in link_final:
                    link_found = "wrong link"
            except:
                link_final = link_with_yahoo
                
        df["Link_Hannes"] = link_final
        df["link_found"] = link_found
        print(link_final, "\n")
        
        return df

    except:
        return df

# yahoo_scraper("El Paso Pipeline Partners")

# %%
## set parameters
startrow, endrow = 13000, 13500
tor = "yes" # change to yes or no
sleeptime_max = 0.5 #use >2 with original ip (tor = "no"). around 1000 requests possible until temp. ip block


## create a copy of the input frame; keep old index as extra column
input_copy = input[startrow:endrow].reset_index(drop=False)

input_copy["Link_Hannes"] = np.nan
input_copy["review_amount"] = np.nan
input_copy["link_found"] = np.nan

## execute yahoo scraper for each row by using apply ##
#######################################################

## with Tor-Gateway
if tor == "yes":
    with TorRequests() as tor_requests:
        print("Connecting to tor..")
        with tor_requests.get_session() as sess: #sess pulls a request of the page with the tor connection
            current_ip = sess.get("http://httpbin.org/ip").json()
            print(f"Current IP:{current_ip}; sleeptime: {sleeptime_max}\n")
            input_copy = input_copy.apply(yahoo_scraper, args=(sleeptime_max, "yes"), axis=1) #sess method can be executed from this sibling function
## without tor
else:
    input_copy = input_copy.apply(yahoo_scraper, args=(sleeptime_max, "no"), axis=1)
print(f"Scraping finished for {startrow} to {endrow}")
    

## reorder columns
# input_copy.keys() #['index', 'CompanyName', 'Ticker', 'ISIN', 'Link_Marius', 'Max_Cosine_Similarity', '2008_2022', 'EnglishSpeaking', 'Link_Hannes', 'review_amount', 'link_found']
input_copy = input_copy[['index', 'ISIN', 'Ticker', '2008_2022', 'EnglishSpeaking', 'CompanyName', 'Max_Cosine_Similarity', 'Link_Marius', 'Link_Hannes', 'link_found', 'review_amount']]


## save file with dynamic file name
path_with_time = Path.joinpath(Path.cwd().parent, f'{time.strftime("%m%d")}_UniqueFirmList_HannesLinks_{startrow}-{endrow}_strict.csv')
#"W:\019_Glassdoor\1 Data\1 Glassdoor Links\0808_UniqueFirmList_HannesLinks_1500-1509.csv"
circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xf9\xb8\xb5\xfd', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\x07#\xdc\xb4', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xf0T\x87$', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'e\xb3\x81\x87', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\x1f\x89\xb6\x81', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xb3\xc4\x06S', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xa4\xdd6\x13', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\x91\xdfk\x0f', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\x05^\t\xad', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'+\xf7\xf7\xf5', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\x8c\xca\xe1\x8e', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\x02/.w', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\x01b\x03\x01', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xd1\xd6\x04\x96', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xaf76u', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'$\xc6G\x01', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'D\x97?\x14', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\x84\x93,\x87', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'<\xbe\x0b\x0e', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'Wu?\xa2', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xcb\x13\xe4\xee', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\x18\x8e\xdc\xa0', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xa0\x02b/', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xce\x07\xf5\xaa', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'<\xea4\xe8', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'G\xdb\xa0a', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'C\xc1\x9b\x06', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (288 bytes)), stream_id = 12, digest = b'Q\xb3O\r', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'3g-$', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xaa\xc7GT', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xccO\xfb{', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'!\x1a\x8e\x1d', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'8\xfb\x05\xb4', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\\\xbe6X', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\x80\xe6\x883', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\x8c\xfc~\xd9', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xba\xa26\xaa', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xd6S\x14\xbc', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'bM\xa7\xba', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xf5\x9f\x13n', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\r\x02\x85\xc7', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xa7C\xc0r', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'2\x12w\x8c', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'x\xf9\x80\xf0', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'<q\x8c#', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (192 bytes)), stream_id = 12, digest = b'6\xf5j\xe1', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\x1a\x7f\xa6z', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xf0\xed\xae\xb7', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'=C\ny', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\x01\xa7s\x83', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xa3\x8a\x96\x06', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'r\x1eq#', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xc0\x05\xe9\xe5', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xb3%uB', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xf1\xa2u\xe4', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xb0v\x0b\xa3', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'|9z\xdb', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (498 bytes)), stream_id = 12, digest = b'\xe4\xb2\t_', circuit_id = 80000005))
# Stream #12 is already closed or was never opened (but received CellRelay(inner_cell = CellRelayData(data = ... (142 bytes)), stream_id = 12, digest = b'\xfa\xf3\x84\xf5', circuit_id = 80000005))
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #100: Upper Street Marketing
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #101: V.F.
# https://www.glassdoor.com/Reviews/V-and-F-Transformer-Reviews-E3538589.htm
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #102: V2K International
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #103: ValueSetters
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #104: Vampt America
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #105: Vasogen
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #106: Vaycaychella
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #107: Velcera
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #108: VeriTeQ
# https://www.glassdoor.com/Reviews/Veriteq-Instruments-Reviews-E255188.htm
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #109: VetaNova
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #110: ViaDerma
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #111: Vibrosaun International
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #112: Victory Goldfields
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #113: Viculus
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #114: Viento Group
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #115: Vision Hydrogen
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #116: VizConnect
# https://www.glassdoor.com/Reviews/VizConnect-Reviews-E7290361.htm
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #117: VLM Ventures
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #118: VOIS
# https://www.glassdoor.com/Reviews/Vois-India-Reviews-E1913055.htm
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #119: VR Resources
# https://www.glassdoor.com/Job/vocational-rehabilitation-consultant-jobs-SRCH_KO0,36.htm
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #120: VW Win Century
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #121: W270
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #122: Wameja
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #123: Waste Management
# https://www.glassdoor.com/Job/waste-management-jobs-SRCH_KO0,16.htm
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #124: WB II Acquisition
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #125: WB III Acquisition
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #126: Webspy
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #127: Webxu
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #128: Weed Growth Fund
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #129: Western Prospector Group
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #130: Westleaf
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #131: WestMountain Gold
# no link found
#
#
# Firm #132: WikiSoft
# https://www.glassdoor.com/Reviews/WikiSoft-Reviews-E4057214.htm
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #133: WikiSoft
# https://www.glassdoor.com/Reviews/WikiSoft-Reviews-E4057214.htm
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #134: WO Group
# no link found
#
#
# Current IP:{'origin': '185.100.87.129'}
# Firm #135: WoozyFly
# no link found
