# %% [markdown]
# ## load data

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import time

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

pd.set_option('display.max_colwidth', None)

df_raw = pd.read_csv(r"W:\019_Glassdoor\1 Data\1 Glassdoor Links\0815_ReviewAmount_English-Post2008.csv", sep=";", decimal=",", encoding='unicode_escape')

# %% [markdown]
# ## prepare data

# %% [markdown]
# #### regex cheat sheet:
#
# https://www.debuggex.com/cheatsheet/regex/python
#
# https://regex101.com/r/3btjRd/4

# %% [markdown]
# ### convert links to firm names

# %%
df = df_raw.copy()

## set links containing SRCH to nan since they appear to be always wrong
df = df.replace({r'(^.*SRCH.*$)': np.nan, 
    r"^.*\/NA\.htm.*": np.nan, #https://www.glassdoor.com/Reviews/NA.htm
    r"^.*\/index\.htm.*": np.nan, #https://www.glassdoor.com/Reviews/index.htm
    r"^.*Glassdoor-Reviews-E100431.*": np.nan}, #https://www.glassdoor.com/Reviews/Glassdoor-Reviews-E100431.htm
    regex=True) 


for index, column in enumerate(["link_marius", "link_hannes", "link_hannes_strict"], start=1):
    ## insert three empty columns after the link columns
    df.insert(df.columns.get_loc("link_hannes_strict")+index, column.replace("link", "firm"), np.nan)
    ## copy links in the empty new columns
    df[column.replace("link", "firm")] = df[column]
    ## remove the https://www.glassdoor.com/Reviews/ part
    df[column.replace("link", "firm")] = df[column.replace("link", "firm")].str.split('/').str[-1]

## convert links to clean firm names
## https://www.glassdoor.com/Reviews/International-Specialty-Products-Reviews-E1114.htm
## to
## International Specialty Products
df[["firm_marius", "firm_hannes", "firm_hannes_strict"]] = df[["firm_marius", "firm_hannes", "firm_hannes_strict"]].replace(
    {"-Reviews|Working-at-":"", 
    r"(?:(-E\d.*)|(-E.*I_.*)\.htm.*$)": "",
    "-": " ",
    "#NAME?": np.nan}, 
    regex=True)

# df["link_found"].unique().tolist()
# wrong link - kann man vergessen
# df = df[df["link_found"]=="transformed jobs link"].reset_index(drop=True)

df.head()
# Out:
#    index          isin ticker  2008_2022  english  \
# 0      0  US0577411004    NaN          1        1
# 1      1  US4603371083    NaN          1        1
# 2      2  CA61945Q1028    NaN          1        1
# 3      3  CA3449191053    NaN          1        1
# 4      4  US5520747008    NaN          1        1
#
#                                   company_name  \
# 0                    ABB Motors and Mechanical
# 1             International Specialty Products
# 2  Conversant Intellectual Property Management
# 3                    Foreign Currency Exchange
# 4                           William Lyon Homes
#
#                                                                                           link_marius  \
# 0                     https://www.glassdoor.com/Reviews/ABB-Motors-and-Mechanical-Inc-Reviews-E73.htm
# 1                https://www.glassdoor.com/Reviews/International-Specialty-Products-Reviews-E1114.htm
# 2  https://www.glassdoor.com/Reviews/Conversant-Intellectual-Property-Management-Reviews-E1014209.htm
# 3                https://www.glassdoor.com/Reviews/Foreign-Currency-Exchange-Corp-Reviews-E260472.htm
# 4                               https://www.glassdoor.com/Reviews/William-Lyon-Homes-Reviews-E258.htm
#
#                                                                                           link_hannes  \
# 0                     https://www.glassdoor.com/Reviews/ABB-Motors-and-Mechanical-Inc-Reviews-E73.htm
# 1                https://www.glassdoor.com/Reviews/International-Specialty-Products-Reviews-E1114.htm
# 2  https://www.glassdoor.com/Reviews/Conversant-Intellectual-Property-Management-Reviews-E1014209.htm
# 3                                                                                                 NaN
# 4                               https://www.glassdoor.com/Reviews/William-Lyon-Homes-Reviews-E258.htm
#
#                                                                                    link_hannes_strict  \
# 0                     https://www.glassdoor.com/Reviews/ABB-Motors-and-Mechanical-Inc-Reviews-E73.htm
# 1                https://www.glassdoor.com/Reviews/International-Specialty-Products-Reviews-E1114.htm
# 2  https://www.glassdoor.com/Reviews/Conversant-Intellectual-Property-Management-Reviews-E1014209.htm
# 3                                                                                                 NaN
# 4                               https://www.glassdoor.com/Reviews/William-Lyon-Homes-Reviews-E258.htm
#
#                                    firm_marius  \
# 0                ABB Motors and Mechanical Inc
# 1             International Specialty Products
# 2  Conversant Intellectual Property Management
# 3               Foreign Currency Exchange Corp
# 4                           William Lyon Homes
#
#                                    firm_hannes  \
# 0                ABB Motors and Mechanical Inc
# 1             International Specialty Products
# 2  Conversant Intellectual Property Management
# 3                                          NaN
# 4                           William Lyon Homes
#
#                             firm_hannes_strict  marius_cosine_original  \
# 0                ABB Motors and Mechanical Inc                0.818978
# 1             International Specialty Products                0.809930
# 2  Conversant Intellectual Property Management                0.806629
# 3                                          NaN                0.798668
# 4                           William Lyon Homes                0.792491
#
#                   link_found          link_found_strict  review_amount  \
# 0  transformed overview link  transformed overview link          201.0
# 1       original review link       original review link            8.0
# 2  transformed overview link  transformed overview link            5.0
# 3                 wrong link                 wrong link            NaN
# 4       original review link       original review link           52.0
#
#    review_amount_strict
# 0                 201.0
# 1                   8.0
# 2                   5.0
# 3                   NaN
# 4                  52.0

# %% [markdown]
# ### string_grouper: calculate cosine similarity

# %%
from string_grouper import compute_pairwise_similarities

df_similarity = df.copy()

## compute_pairwise_similarities method cant handle np.nan -> use empty strings
df_similarity[["firm_marius", "firm_hannes", "firm_hannes_strict"]] = df_similarity[["firm_marius", "firm_hannes", "firm_hannes_strict"]].replace(np.nan, "")

for column in ["firm_marius", "firm_hannes", "firm_hannes_strict"]:
    df_similarity[column.replace("firm", "similarity")] = round(
        compute_pairwise_similarities(df_similarity["company_name"], df_similarity[column], ignore_case=True, ngram_size=3),
        2)

## get the mean of the three cosine scores
df_similarity["similarity_mean"] = df_similarity[["similarity_marius", "similarity_hannes", "similarity_hannes_strict"]].mean(axis=1)

## check whether firm name of marius is equal to hannes
df_similarity["marius_equalto_hannes"] = np.where( (df_similarity["firm_marius"] == df_similarity["firm_hannes"]) | (df_similarity["firm_marius"] == df_similarity["firm_hannes_strict"]),  1, 0)

## get the firm name of the max cos value
df_similarity.insert(df_similarity.columns.get_loc("company_name")+1, "best_match", np.nan)
## get the column name with the highest similarity value
best_matches = df_similarity[["similarity_marius", "similarity_hannes", "similarity_hannes_strict"]].idxmax(axis=1).replace({"similarity": "firm"}, regex=True).tolist()
## assign the highest match to the best_match column
for index, columnname in enumerate(best_matches):
    df_similarity.loc[index, "best_match"] = df_similarity.loc[index, columnname]

df_similarity[:4]
# Out:
#    index          isin ticker  2008_2022  english  \
# 0      0  US0577411004    NaN          1        1
# 1      1  US4603371083    NaN          1        1
# 2      2  CA61945Q1028    NaN          1        1
# 3      3  CA3449191053    NaN          1        1
#
#                                   company_name  \
# 0                    ABB Motors and Mechanical
# 1             International Specialty Products
# 2  Conversant Intellectual Property Management
# 3                    Foreign Currency Exchange
#
#                                     best_match  \
# 0                ABB Motors and Mechanical Inc
# 1             International Specialty Products
# 2  Conversant Intellectual Property Management
# 3               Foreign Currency Exchange Corp
#
#                                                                                           link_marius  \
# 0                     https://www.glassdoor.com/Reviews/ABB-Motors-and-Mechanical-Inc-Reviews-E73.htm
# 1                https://www.glassdoor.com/Reviews/International-Specialty-Products-Reviews-E1114.htm
# 2  https://www.glassdoor.com/Reviews/Conversant-Intellectual-Property-Management-Reviews-E1014209.htm
# 3                https://www.glassdoor.com/Reviews/Foreign-Currency-Exchange-Corp-Reviews-E260472.htm
#
#                                                                                           link_hannes  \
# 0                     https://www.glassdoor.com/Reviews/ABB-Motors-and-Mechanical-Inc-Reviews-E73.htm
# 1                https://www.glassdoor.com/Reviews/International-Specialty-Products-Reviews-E1114.htm
# 2  https://www.glassdoor.com/Reviews/Conversant-Intellectual-Property-Management-Reviews-E1014209.htm
# 3                                                                                                 NaN
#
#                                                                                    link_hannes_strict  \
# 0                     https://www.glassdoor.com/Reviews/ABB-Motors-and-Mechanical-Inc-Reviews-E73.htm
# 1                https://www.glassdoor.com/Reviews/International-Specialty-Products-Reviews-E1114.htm
# 2  https://www.glassdoor.com/Reviews/Conversant-Intellectual-Property-Management-Reviews-E1014209.htm
# 3                                                                                                 NaN
#
#    ... marius_cosine_original                 link_found  \
# 0  ...               0.818978  transformed overview link
# 1  ...               0.809930       original review link
# 2  ...               0.806629  transformed overview link
# 3  ...               0.798668                 wrong link
#
#            link_found_strict  review_amount review_amount_strict  \
# 0  transformed overview link          201.0                201.0
# 1       original review link            8.0                  8.0
# 2  transformed overview link            5.0                  5.0
# 3                 wrong link            NaN                  NaN
#
#   similarity_marius  similarity_hannes  similarity_hannes_strict  \
# 0              0.96               0.96                      0.96
# 1              1.00               1.00                      1.00
# 2              1.00               1.00                      1.00
# 3              0.95               0.00                      0.00
#
#    similarity_mean  marius_equalto_hannes
# 0         0.960000                      1
# 1         1.000000                      1
# 2         1.000000                      1
# 3         0.316667                      0
#
# [4 rows x 23 columns]

# %% [markdown]
# ### merge with target_dummy and clean duplicates

# %%
df_target = pd.read_excel(r"W:\019_Glassdoor\1 Data\1 Glassdoor Links\Archive\target_dummy_list.xlsx")

## one isin can have a 0 and 1 entry -> drop the second (0) entry
df_target.sort_values(by=["target_dummy"], ascending=[0], inplace=True)
df_target.reset_index(drop=True, inplace=True)

df_target.drop_duplicates(subset=["isin"], keep="first", inplace=True)

## vlookup if firm has ever been a target
df_similarity = df_similarity.merge(df_target, how="left", on="isin")

# shift column next to ticker column
poped_col = df_similarity.pop('target_dummy')
df_similarity.insert(df_similarity.columns.get_loc("ticker")+1, 'target_dummy', poped_col)

## drop duplicate rows
df_similarity.drop_duplicates(subset=["isin", "target_dummy", "similarity_mean"], keep="first", inplace=True)

## sort by
df_similarity.sort_values(by=["similarity_mean", "target_dummy", "review_amount"], ascending=[0, 0, 0], inplace=True)

df_similarity[200:230]
# Out:
#        index          isin         ticker  target_dummy  2008_2022  english  \
# 11454  11454  US6294911010            NaN             1          1        1
# 2362    2362  US1413371055            NaN             1          1        1
# 884      884  US5949011002            NaN             1          1        1
# 2347    2347  US5537771033            NaN             1          1        1
# 5412    5412  US1313473043            NaN             1          1        1
# 2342    2342  US45840J1079            NaN             1          1        1
# 3227    3227  US8978881030            NaN             1          1        1
# 9951    9951  US89969Q1040            NaN             1          1        1
# 318      318  US75968L1052            NaN             1          1        1
# 4692    4692  US71714F1049            NaN             1          1        1
# 801      801  CA83172R2072            NaN             1          1        1
# 2760    2760  US7565771026            NaN             1          1        1
# 666      666  US0204091088            NaN             1          1        1
# 4068    4068  US39813G1094  NasdaqCM:GDYN             1          1        1
# 9424    9424  US77285P1084            NaN             1          1        1
# 331      331  US02369E1001            NaN             1          1        1
# 514      514  US72348P1049            NaN             1          1        1
# 2870    2870  US4408941031            NaN             1          1        1
# 5467    5467  US4989042001            NaN             1          1        1
# 881      881  US3798901068            NaN             1          1        1
# 3252    3252  US6518241046            NaN             1          1        1
# 4658    4658  US45071R1095            NaN             1          1        1
# 7728    7728  CA1254911003        TSX:CIX             1          1        1
# 1627    1627  US03349M1053            NaN             1          1        1
# 1054    1054  US47760A1088            NaN             1          1        1
# 1513    1513  US65342H1023            NaN             1          1        1
# 4015    4015  US92854C1071            NaN             1          1        1
# 6045    6045  US4888791070            NaN             1          1        1
# 3375    3375  US8252111054            NaN             1          1        1
# 4204    4204  GB0008762899            NaN             1          1        1
#
#                      company_name                  best_match  \
# 11454                        NYSE                        NYSE
# 2362                    Carbonite                   Carbonite
# 884                MICROS Systems              MICROS Systems
# 2347                  MTS Systems                 MTS Systems
# 5412                      Calpine                     Calpine
# 2342             Interactive Data            Interactive Data
# 3227                       Trulia                      Trulia
# 9951                         Tumi                        Tumi
# 318          Renaissance Learning        Renaissance Learning
# 4692                   PharMerica                  PharMerica
# 801            Smart Technologies          SMART Technologies
# 2760                      Red Hat                     Red Hat
# 666                 Almost Family               Almost Family
# 4068               Grid Dynamics                Grid Dynamics
# 9424                          DTI                         DTI
# 331    American Addiction Centers  American Addiction Centers
# 514                Pinnacle Foods              Pinnacle Foods
# 2870                  Hortonworks                 Hortonworks
# 5467                        Knoll                       Knoll
# 881                    Glu Mobile                  Glu Mobile
# 3252                      Newport                     Newport
# 4658                         Ixia                        Ixia
# 7728                CI Financial                 CI Financial
# 1627                     Andeavor                    Andeavor
# 1054                Jive Software               Jive Software
# 1513              Nexeo Solutions             Nexeo Solutions
# 4015                       Vivial                      Vivial
# 6045                       Kenexa                      Kenexa
# 3375                     ShoreTel                    ShoreTel
# 4204                     BG Group                    BG Group
#
#                                                                             link_marius  \
# 11454                          https://www.glassdoor.com/Reviews/NYSE-Reviews-E3307.htm
# 2362                    https://www.glassdoor.com/Reviews/Carbonite-Reviews-E304976.htm
# 884                  https://www.glassdoor.com/Reviews/MICROS-Systems-Reviews-E1649.htm
# 2347                    https://www.glassdoor.com/Reviews/MTS-Systems-Reviews-E1608.htm
# 5412                        https://www.glassdoor.com/Reviews/Calpine-Reviews-E6150.htm
# 2342               https://www.glassdoor.com/Reviews/Interactive-Data-Reviews-E3644.htm
# 3227                       https://www.glassdoor.com/Reviews/Trulia-Reviews-E226815.htm
# 9951                          https://www.glassdoor.com/Reviews/Tumi-Reviews-E20782.htm
# 318            https://www.glassdoor.com/Reviews/Renaissance-Learning-Reviews-E6746.htm
# 4692                      https://www.glassdoor.com/Reviews/PharMerica-Reviews-E894.htm
# 801             https://www.glassdoor.com/Reviews/SMART-Technologies-Reviews-E30897.htm
# 2760           https://www.glassdoor.com/Reviews/Working-at-Red-Hat-EI_IE8868.11,18.htm
# 666                   https://www.glassdoor.com/Reviews/Almost-Family-Reviews-E4784.htm
# 4068                https://www.glassdoor.com/Reviews/Grid-Dynamics-Reviews-E245799.htm
# 9424                          https://www.glassdoor.com/Reviews/DTI-Reviews-E241200.htm
# 331    https://www.glassdoor.com/Reviews/American-Addiction-Centers-Reviews-E656512.htm
# 514                  https://www.glassdoor.com/Reviews/Pinnacle-Foods-Reviews-E6882.htm
# 2870               https://www.glassdoor.com/Reviews/Hortonworks-Reviews-E489054_P3.htm
# 5467                          https://www.glassdoor.com/Reviews/Knoll-Reviews-E5511.htm
# 881                     https://www.glassdoor.com/Reviews/Glu-Mobile-Reviews-E16224.htm
# 3252                        https://www.glassdoor.com/Reviews/Newport-Reviews-E1696.htm
# 4658              https://www.glassdoor.com/Reviews/Working-at-Ixia-EI_IE9341.11,15.htm
# 7728                 https://www.glassdoor.com/Reviews/CI-Financial-Reviews-E354908.htm
# 1627                    https://www.glassdoor.com/Reviews/Andeavor-Reviews-E1743656.htm
# 1054                https://www.glassdoor.com/Reviews/Jive-Software-Reviews-E157126.htm
# 1513           https://www.glassdoor.com/Reviews/Nexeo-Solutions-Reviews-E419397_P3.htm
# 4015                      https://www.glassdoor.com/Reviews/Vivial-Reviews-E1310485.htm
# 6045                        https://www.glassdoor.com/Reviews/Kenexa-Reviews-E12138.htm
# 3375                       https://www.glassdoor.com/Reviews/ShoreTel-Reviews-E9479.htm
# 4204                      https://www.glassdoor.com/Reviews/BG-Group-Reviews-E10128.htm
#
#                                                                             link_hannes  \
# 11454                          https://www.glassdoor.com/Reviews/NYSE-Reviews-E3307.htm
# 2362                    https://www.glassdoor.com/Reviews/Carbonite-Reviews-E304976.htm
# 884                  https://www.glassdoor.com/Reviews/MICROS-Systems-Reviews-E1649.htm
# 2347                    https://www.glassdoor.com/Reviews/MTS-Systems-Reviews-E1608.htm
# 5412                        https://www.glassdoor.com/Reviews/Calpine-Reviews-E6150.htm
# 2342               https://www.glassdoor.com/Reviews/Interactive-Data-Reviews-E3644.htm
# 3227                       https://www.glassdoor.com/Reviews/Trulia-Reviews-E226815.htm
# 9951                          https://www.glassdoor.com/Reviews/Tumi-Reviews-E20782.htm
# 318            https://www.glassdoor.com/Reviews/Renaissance-Learning-Reviews-E6746.htm
# 4692                      https://www.glassdoor.com/Reviews/PharMerica-Reviews-E894.htm
# 801             https://www.glassdoor.com/Reviews/SMART-Technologies-Reviews-E30897.htm
# 2760                        https://www.glassdoor.com/Reviews/Red-Hat-Reviews-E8868.htm
# 666                   https://www.glassdoor.com/Reviews/Almost-Family-Reviews-E4784.htm
# 4068                https://www.glassdoor.com/Reviews/Grid-Dynamics-Reviews-E245799.htm
# 9424                          https://www.glassdoor.com/Reviews/DTI-Reviews-E241200.htm
# 331    https://www.glassdoor.com/Reviews/American-Addiction-Centers-Reviews-E656512.htm
# 514                  https://www.glassdoor.com/Reviews/Pinnacle-Foods-Reviews-E6882.htm
# 2870                  https://www.glassdoor.com/Reviews/Hortonworks-Reviews-E489054.htm
# 5467                          https://www.glassdoor.com/Reviews/Knoll-Reviews-E5511.htm
# 881                     https://www.glassdoor.com/Reviews/Glu-Mobile-Reviews-E16224.htm
# 3252                      https://www.glassdoor.com/Reviews/Newport-Reviews-E222630.htm
# 4658                           https://www.glassdoor.com/Reviews/Ixia-Reviews-E9341.htm
# 7728                 https://www.glassdoor.com/Reviews/CI-Financial-Reviews-E354908.htm
# 1627                    https://www.glassdoor.com/Reviews/Andeavor-Reviews-E1743656.htm
# 1054                https://www.glassdoor.com/Reviews/Jive-Software-Reviews-E157126.htm
# 1513              https://www.glassdoor.com/Reviews/Nexeo-Solutions-Reviews-E419397.htm
# 4015                      https://www.glassdoor.com/Reviews/Vivial-Reviews-E1310485.htm
# 6045                        https://www.glassdoor.com/Reviews/Kenexa-Reviews-E12138.htm
# 3375                       https://www.glassdoor.com/Reviews/ShoreTel-Reviews-E9479.htm
# 4204                      https://www.glassdoor.com/Reviews/BG-Group-Reviews-E10128.htm
#
#        ... marius_cosine_original                 link_found  \
# 11454  ...               0.122000  transformed overview link
# 2362   ...               0.496537       original review link
# 884    ...               0.607351  transformed overview link
# 2347   ...               0.497428       original review link
# 5412   ...               0.365136  transformed overview link
# 2342   ...               0.497701       original review link
# 3227   ...               0.453943  transformed overview link
# 9951   ...               0.198976  transformed overview link
# 318    ...               0.678412  transformed overview link
# 4692   ...               0.392168  transformed overview link
# 801    ...               0.614717  transformed overview link
# 2760   ...               0.474989  transformed overview link
# 666    ...               0.631534  transformed overview link
# 4068   ...               0.418282  transformed overview link
# 9424   ...               0.220912  transformed overview link
# 331    ...               0.675778  transformed overview link
# 514    ...               0.650085  transformed overview link
# 2870   ...               0.470183  transformed overview link
# 5467   ...               0.362673  transformed overview link
# 881    ...               0.607571  transformed overview link
# 3252   ...               0.452855  transformed overview link
# 4658   ...               0.393533  transformed overview link
# 7728   ...               0.282206  transformed overview link
# 1627   ...               0.546064  transformed overview link
# 1054   ...               0.591636  transformed overview link
# 1513   ...               0.555108  transformed overview link
# 4015   ...               0.420304  transformed overview link
# 6045   ...               0.341658  transformed overview link
# 3375   ...               0.448181  transformed overview link
# 4204   ...               0.412667  transformed overview link
#
#                link_found_strict review_amount  review_amount_strict  \
# 11454  transformed overview link         318.0                 318.0
# 2362   transformed overview link         314.0                 294.0
# 884    transformed overview link         312.0                 312.0
# 2347        original review link         309.0                 309.0
# 5412   transformed overview link         306.0                 306.0
# 2342        original review link         305.0                 305.0
# 3227   transformed overview link         304.0                 304.0
# 9951   transformed overview link         304.0                 304.0
# 318    transformed overview link         303.0                 303.0
# 4692   transformed overview link         303.0                 303.0
# 801    transformed overview link         300.0                 300.0
# 2760   transformed overview link         300.0                 300.0
# 666    transformed overview link         295.0                 295.0
# 4068   transformed overview link         295.0                 295.0
# 9424   transformed overview link         293.0                 293.0
# 331    transformed overview link         292.0                 292.0
# 514    transformed overview link         292.0                 292.0
# 2870   transformed overview link         290.0                 290.0
# 5467       transformed jobs link         289.0                   NaN
# 881    transformed overview link         288.0                 288.0
# 3252   transformed overview link         281.0                 281.0
# 4658   transformed overview link         281.0                 281.0
# 7728   transformed overview link         281.0                 281.0
# 1627   transformed overview link         277.0                 277.0
# 1054   transformed overview link         275.0                 275.0
# 1513        original review link         275.0                 283.0
# 4015   transformed overview link         274.0                 274.0
# 6045   transformed overview link         274.0                 274.0
# 3375   transformed overview link         271.0                 271.0
# 4204   transformed overview link         271.0                 271.0
#
#       similarity_marius similarity_hannes  similarity_hannes_strict  \
# 11454               1.0               1.0                       1.0
# 2362                1.0               1.0                       1.0
# 884                 1.0               1.0                       1.0
# 2347                1.0               1.0                       1.0
# 5412                1.0               1.0                       1.0
# 2342                1.0               1.0                       1.0
# 3227                1.0               1.0                       1.0
# 9951                1.0               1.0                       1.0
# 318                 1.0               1.0                       1.0
# 4692                1.0               1.0                       1.0
# 801                 1.0               1.0                       1.0
# 2760                1.0               1.0                       1.0
# 666                 1.0               1.0                       1.0
# 4068                1.0               1.0                       1.0
# 9424                1.0               1.0                       1.0
# 331                 1.0               1.0                       1.0
# 514                 1.0               1.0                       1.0
# 2870                1.0               1.0                       1.0
# 5467                1.0               1.0                       1.0
# 881                 1.0               1.0                       1.0
# 3252                1.0               1.0                       1.0
# 4658                1.0               1.0                       1.0
# 7728                1.0               1.0                       1.0
# 1627                1.0               1.0                       1.0
# 1054                1.0               1.0                       1.0
# 1513                1.0               1.0                       1.0
# 4015                1.0               1.0                       1.0
# 6045                1.0               1.0                       1.0
# 3375                1.0               1.0                       1.0
# 4204                1.0               1.0                       1.0
#
#        similarity_mean  marius_equalto_hannes
# 11454              1.0                      1
# 2362               1.0                      1
# 884                1.0                      1
# 2347               1.0                      1
# 5412               1.0                      1
# 2342               1.0                      1
# 3227               1.0                      1
# 9951               1.0                      1
# 318                1.0                      1
# 4692               1.0                      1
# 801                1.0                      1
# 2760               1.0                      1
# 666                1.0                      1
# 4068               1.0                      1
# 9424               1.0                      1
# 331                1.0                      1
# 514                1.0                      1
# 2870               1.0                      1
# 5467               1.0                      1
# 881                1.0                      1
# 3252               1.0                      1
# 4658               1.0                      1
# 7728               1.0                      1
# 1627               1.0                      1
# 1054               1.0                      1
# 1513               1.0                      1
# 4015               1.0                      1
# 6045               1.0                      1
# 3375               1.0                      1
# 4204               1.0                      1
#
# [30 rows x 24 columns]

# %%
## save file with dynamic file name
path_with_time = Path.joinpath(Path.cwd().parent, f'{time.strftime("%m%d")}_LinksNamesReviews_bestmatch.csv')
df_similarity.to_csv(path_with_time, sep=";", decimal=",", index=False)
print(f"{path_with_time} saved")
# Out:
# w:\019_Glassdoor\1 Data\1 Glassdoor Links\0816_LinksNamesReviews_bestmatch.csv saved

# %%
similarity_thresholds = list(map(lambda x: x/10.0, range(5, 11, 1))) #range doesnt work with floats
min_review_amounts = [i for i in range(30,80,10)]

for min_review_amount in min_review_amounts:
    for similarity_threshold in similarity_thresholds:
        rows = df_similarity[ (df_similarity["mean"] >= similarity_threshold) & (df_similarity["target_dummy"] == 1) & (df_similarity["review_amount"] >= min_review_amount)].shape[0]
        print(f"min review amount treshold: {min_review_amount} & similarity_threshold: {similarity_threshold} -> {rows} targets")
    print("\n")
# Out:
# min review amount treshold: 30 & similarity_threshold: 0.5 -> 1363 targets
# min review amount treshold: 30 & similarity_threshold: 0.6 -> 1187 targets
# min review amount treshold: 30 & similarity_threshold: 0.7 -> 1046 targets
# min review amount treshold: 30 & similarity_threshold: 0.8 -> 884 targets
# min review amount treshold: 30 & similarity_threshold: 0.9 -> 723 targets
# min review amount treshold: 30 & similarity_threshold: 1.0 -> 684 targets
#
#
# min review amount treshold: 40 & similarity_threshold: 0.5 -> 1224 targets
# min review amount treshold: 40 & similarity_threshold: 0.6 -> 1065 targets
# min review amount treshold: 40 & similarity_threshold: 0.7 -> 935 targets
# min review amount treshold: 40 & similarity_threshold: 0.8 -> 797 targets
# min review amount treshold: 40 & similarity_threshold: 0.9 -> 652 targets
# min review amount treshold: 40 & similarity_threshold: 1.0 -> 620 targets
#
#
# min review amount treshold: 50 & similarity_threshold: 0.5 -> 1119 targets
# min review amount treshold: 50 & similarity_threshold: 0.6 -> 975 targets
# min review amount treshold: 50 & similarity_threshold: 0.7 -> 863 targets
# min review amount treshold: 50 & similarity_threshold: 0.8 -> 734 targets
# min review amount treshold: 50 & similarity_threshold: 0.9 -> 598 targets
# min review amount treshold: 50 & similarity_threshold: 1.0 -> 569 targets
#
#
# min review amount treshold: 60 & similarity_threshold: 0.5 -> 1027 targets
# min review amount treshold: 60 & similarity_threshold: 0.6 -> 895 targets
# min review amount treshold: 60 & similarity_threshold: 0.7 -> 791 targets
# min review amount treshold: 60 & similarity_threshold: 0.8 -> 674 targets
# min review amount treshold: 60 & similarity_threshold: 0.9 -> 550 targets
# min review amount treshold: 60 & similarity_threshold: 1.0 -> 522 targets
#
#
# min review amount treshold: 70 & similarity_threshold: 0.5 -> 954 targets
# min review amount treshold: 70 & similarity_threshold: 0.6 -> 830 targets
# min review amount treshold: 70 & similarity_threshold: 0.7 -> 737 targets
# min review amount treshold: 70 & similarity_threshold: 0.8 -> 629 targets
# min review amount treshold: 70 & similarity_threshold: 0.9 -> 518 targets
# min review amount treshold: 70 & similarity_threshold: 1.0 -> 490 targets

# %% [markdown]
# ## examples

# %% [markdown]
# ### vectorize strings & calc cosine similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

def text_similarity(row, column_name1, column_name2):
    ## vectorize strings to word count lists
    count_vect = CountVectorizer(lowercase=True) #object needs to be initialized for the (optional) df later on
    texts = [row[column_name1],row[column_name2]]
    vectorized_texts_object = count_vect.fit_transform(texts)
    vectorized_texts = vectorized_texts_object.toarray() #2 list entries

    ## calc cosine similarity (0-1; with 1 being perfectly identical)
    similarity = cosine_similarity([vectorized_texts[0]], [vectorized_texts[1]])
    similarity_score = round(float(similarity),3)
    return similarity_score

# %%
df["Max_Cosine_Similarity_Hannes"] = df.apply(text_similarity, args=("company_name", "company_name"), axis=1) #args to set both column names that should be used
df

# %% [markdown]
# ### example: vectorize strings & calc cosine similarity

# %%
def text_similarity(text1, text2):
    ## vectorize strings to word count lists
    count_vect = CountVectorizer(lowercase=True) #object needs to be initialized for the (optional) df later on
    texts = [text1,text2]
    vectorized_texts_object = count_vect.fit_transform(texts)
    vectorized_texts = vectorized_texts_object.toarray() #2 list entries

    df_vectorized_texts = pd.DataFrame(vectorized_texts_object.toarray(),columns=count_vect.get_feature_names_out(),index=["text1", "text2"])
    print(df_vectorized_texts)

    # print(vectorized_texts[0])
    # print(vectorized_texts[1])

    ## calc cosine similarity (0-1; with 1 being perfectly identical)
    similarity = cosine_similarity([vectorized_texts[0]], [vectorized_texts[1]])
    similarity_score = round(float(similarity),3)
    return similarity_score


text1 = "Champignon Brands"
text2 = "Champion Brands"
text_similarity(text1, text2)

# %% [markdown]
# #### Levinshtein Distance

# %%
from fuzzywuzzy import fuzz
# df['score'] = df[['Name Left','Name Right']].apply(lambda x : fuzz.partial_ratio(*x),axis=1)

text1 = "Champignon Brands"
text2 = "Champion Brands"
fuzz.partial_ratio(text1, text2)

# %% [markdown]
# ### String_Grouper Module

# %%
from string_grouper import compute_pairwise_similarities

# Create a small DataFrame of pairs of strings:
pair_s = pd.DataFrame(
    [
        ('Mega Enterprises Corporation', 'Mega Enterprises Corporation'),
        ('Hyper Startup Inc.', 'Hyper Startup Incorporated'),
        ('Hyper Startup Inc.', 'Hyper Startup Inc.'),
        ('Hyper Startup Inc.', 'Hyper-Startup Inc.'),
        ('Hyper Hyper Inc.', 'Hyper Hyper Inc.'),
        ('Mega Enterprises Corporation', 'Mega Enterprises Corp.')
   ],
   columns=('left', 'right')
)

pair_s['similarity'] = compute_pairwise_similarities(pair_s['left'], pair_s['right'])
pair_s
